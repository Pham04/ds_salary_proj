# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from shutil import which
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, ElementNotInteractableException
import pandas as pd
import time


def fetch_jobs(keyword, num_pages):
    options = Options()
    options.add_argument("window-size=1920,1080")
    #Enter your chromedriver.exe path below
    chrome_path = r"D:\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"
    service = Service(executable_path=chrome_path)
    driver = webdriver.Chrome(service=service, options=options)
    driver.get("https://www.glassdoor.co.in/Job/Home/recentActivity.htm")
    search_input = driver.find_element(By.ID, "sc.keyword")
    search_input.send_keys(keyword)
    search_input.send_keys(Keys.ENTER)
    time.sleep(2)
    
    
    
    
    company_name = []
    job_title = []
    salary_est = []
    location = []
    job_description = []
    salary_estimate = []
    company_size = []
    company_type = []
    company_sector = []
    company_industry = []
    company_founded = []
    company_revenue = []
    
    
    
    #Set current page to 1
    current_page = 1     
        
        
    time.sleep(3)
    
    while current_page <= num_pages:   
        
        done = False
        while not done:
            job_cards = driver.find_elements("xpath","//article[@id='MainCol']//ul/li[@data-adv-type='GENERAL']")
            for card in job_cards:
                card.click()
                time.sleep(1)

                #Closes the signup prompt
                try:
                    driver.find_element("xpath",".//button[@class='e1jbctw80 ei0fd8p1 css-1n14mz9 e1q8sty40']").click()
                    time.sleep(2)
                except NoSuchElementException:
                    time.sleep(2)
                    pass

                #Expands the Description section by clicking on Show More
#                 try:
#                     driver.find_element("xpath","//div[@class='css-t3xrds e856ufb4']").click()
#                     time.sleep(1)
#                 except NoSuchElementException:
#                     card.click()
#                     print(str(current_page) + '#ERROR: no such element')
#                     time.sleep(30)
#                     driver.find_element("xpath","//div[@class='css-t3xrds e856ufb2']").click()
#                 except ElementNotInteractableException:
#                     card.click()
#                     driver.implicitly_wait(30)
#                     print(str(current_page) + '#ERROR: not interactable')
#                     driver.find_element("xpath","//div[@class='css-t3xrds e856ufb2']").click()

                #Scrape 

                try:
                    company_name.append(driver.find_element("xpath","//div[@class='css-87uc0g e1tk4kwz1']").text)
                except:
                    company_name.append("#N/A")
                    pass

                try:
                    job_title.append(driver.find_element("xpath","//div[@class='css-1vg6q84 e1tk4kwz4']").text)
                except:
                    job_title.append("#N/A")
                    pass

                try:
                    location.append(driver.find_element("xpath","//div[@class='css-56kyx5 e1tk4kwz5']").text)
                except:
                    location.append("#N/A")
                    pass

                try:
                    job_description.append(driver.find_element("xpath","//div[@id='JobDescriptionContainer']").text)
                except:
                    job_description.append("#N/A")
                    pass

                try:
                    whole_salary = driver.find_element("xpath","//span[@class='css-1xe2xww e1wijj242']").text
                    prefix_salary = driver.find_elements("xpath","//span[@class='css-1xe2xww e1wijj242']/*")[0].text
                    salary_i = whole_salary.replace(prefix_salary, "")
                    salary_estimate.append(salary_i)
                except:
                    salary_estimate.append("#N/A")
                    pass
                
                try:
                    company_size.append(driver.find_element("xpath","//div[@id='CompanyContainer']//span[text()='Size']//following-sibling::*").text)
                except:
                    company_size.append("#N/A")
                    pass
                
                try:
                    company_type.append(driver.find_element("xpath","//div[@id='CompanyContainer']//span[text()='Type']//following-sibling::*").text)
                except:
                    company_type.append("#N/A")
                    pass
                    
                try:
                    company_sector.append(driver.find_element("xpath","//div[@id='CompanyContainer']//span[text()='Sector']//following-sibling::*").text)
                except:
                    company_sector.append("#N/A")
                    pass
                    
                try:
                    company_industry.append(driver.find_element("xpath","//div[@id='CompanyContainer']//span[text()='Industry']//following-sibling::*").text)
                except:
                    company_industry.append("#N/A")
                    pass
                    
                try:
                    company_founded.append(driver.find_element("xpath","//div[@id='CompanyContainer']//span[text()='Founded']//following-sibling::*").text)
                except:
                    company_founded.append("#N/A")
                    pass
                    
                try:
                    company_revenue.append(driver.find_element("xpath","//div[@id='CompanyContainer']//span[text()='Revenue']//following-sibling::*").text)
                except:
                    company_revenue.append("#N/A")
                    pass
                    
                    
                    
                    
                done = True
                
       # Moves to the next page         
        if done:
            print(str(current_page) + ' ' + 'out of' +' '+ str(num_pages) + ' ' + 'pages done')
            driver.find_element("xpath","//button[@class='nextButton job-search-opoz2d e13qs2072']").click()   
            current_page = current_page + 1
            time.sleep(4)
            




    driver.close()
    df = pd.DataFrame({'company': company_name, 
    'job title': job_title,
    'location': location,
    'job description': job_description,
    'salary estimate': salary_estimate,
    'company_size': company_size,
    'company_type': company_type,
    'company_sector': company_sector,
    'company_industry' : company_industry, 'company_founded' : company_founded, 'company_revenue': company_revenue})
    
    df.to_csv(keyword + '.csv')

# %%
fetch_jobs("Data Science", 30)
# Out:
# #N/A
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹7L - ₹11L
# Employer Provided Salary:
# ₹7L - ₹11L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# ₹5L - ₹10L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹10L
# #N/A
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹7L - ₹8L
# Employer Provided Salary:
# ₹7L - ₹8L
# Employer Provided Salary:₹4L
# Employer Provided Salary:
# ₹4L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹50L - ₹74L
# Employer Provided Salary:
# ₹50L - ₹74L
# ₹2L - ₹3L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹2L - ₹3L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# ₹6L - ₹7L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹6L - ₹7L
# ₹2L - ₹3L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹2L - ₹3L
# #N/A
# Employer Provided Salary:₹20T - ₹25T
# Employer Provided Salary:
# ₹20T - ₹25T
# #N/A
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# Employer Provided Salary:₹3L - ₹10L
# Employer Provided Salary:
# ₹3L - ₹10L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# 1 out of 30 pages done
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# #N/A
# Employer Provided Salary:₹5L - ₹10L
# Employer Provided Salary:
# ₹5L - ₹10L
# Employer Provided Salary:₹16L
# Employer Provided Salary:
# ₹16L
# #N/A
# Employer Provided Salary:₹35T - ₹50T
# Employer Provided Salary:
# ₹35T - ₹50T
# #N/A
# #N/A
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# Employer Provided Salary:₹8L
# Employer Provided Salary:
# ₹8L
# #N/A
# Employer Provided Salary:₹3L
# Employer Provided Salary:
# ₹3L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹4L - ₹12L
# Employer Provided Salary:
# ₹4L - ₹12L
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# #N/A
# #N/A
# Employer Provided Salary:₹12L - ₹15L
# Employer Provided Salary:
# ₹12L - ₹15L
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# ₹6L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹6L - ₹9L
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# 2 out of 30 pages done
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# #N/A
# Employer Provided Salary:₹3L
# Employer Provided Salary:
# ₹3L
# Employer Provided Salary:₹35T - ₹50T
# Employer Provided Salary:
# ₹35T - ₹50T
# Employer Provided Salary:₹16L
# Employer Provided Salary:
# ₹16L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# Employer Provided Salary:₹8L
# Employer Provided Salary:
# ₹8L
# #N/A
# Employer Provided Salary:₹5L - ₹10L
# Employer Provided Salary:
# ₹5L - ₹10L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹3L - ₹4L
# Employer Provided Salary:
# ₹3L - ₹4L
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# #N/A
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# Employer Provided Salary:₹12L - ₹15L
# Employer Provided Salary:
# ₹12L - ₹15L
# ₹2L - ₹3L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹2L - ₹3L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# 3 out of 30 pages done
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# #N/A
# Employer Provided Salary:₹35T - ₹50T
# Employer Provided Salary:
# ₹35T - ₹50T
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# #N/A
# Employer Provided Salary:₹16L
# Employer Provided Salary:
# ₹16L
# Employer Provided Salary:₹8L
# Employer Provided Salary:
# ₹8L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹3L - ₹4L
# Employer Provided Salary:
# ₹3L - ₹4L
# #N/A
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹9L
# Employer Provided Salary:
# ₹9L
# Employer Provided Salary:₹12L - ₹15L
# Employer Provided Salary:
# ₹12L - ₹15L
# #N/A
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# ₹6L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹6L - ₹8L
# Employer Provided Salary:₹4L - ₹8L
# Employer Provided Salary:
# ₹4L - ₹8L
# ₹7L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹7L - ₹9L
# ₹4L - ₹10L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹10L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# 4 out of 30 pages done
# #N/A
# #N/A
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹35T - ₹50T
# Employer Provided Salary:
# ₹35T - ₹50T
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹16L
# Employer Provided Salary:
# ₹16L
# Employer Provided Salary:₹8L
# Employer Provided Salary:
# ₹8L
# #N/A
# #N/A
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# ₹4L - ₹4L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹4L
# #N/A
# Employer Provided Salary:₹9L
# Employer Provided Salary:
# ₹9L
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# Employer Provided Salary:₹8T - ₹10T
# Employer Provided Salary:
# ₹8T - ₹10T
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# #N/A
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# 5 out of 30 pages done
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# #N/A
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹35T - ₹50T
# Employer Provided Salary:
# ₹35T - ₹50T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹8L
# Employer Provided Salary:
# ₹8L
# #N/A
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# ₹4L - ₹10L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹10L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹4L - ₹4L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹4L
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# #N/A
# Employer Provided Salary:₹8T - ₹10T
# Employer Provided Salary:
# ₹8T - ₹10T
# #N/A
# #N/A
# #N/A
# Employer Provided Salary:₹9L
# Employer Provided Salary:
# ₹9L
# ₹2L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹2L - ₹8L
# ₹4L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹5L
# 6 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# #N/A
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹35T - ₹50T
# Employer Provided Salary:
# ₹35T - ₹50T
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹3L
# Employer Provided Salary:
# ₹3L
# #N/A
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# Employer Provided Salary:₹20T - ₹25T
# Employer Provided Salary:
# ₹20T - ₹25T
# 7 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# #N/A
# Employer Provided Salary:₹20T - ₹25T
# Employer Provided Salary:
# ₹20T - ₹25T
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# #N/A
# Employer Provided Salary:₹3L
# Employer Provided Salary:
# ₹3L
# #N/A
# 8 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹20T - ₹25T
# Employer Provided Salary:
# ₹20T - ₹25T
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# 9 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# #N/A
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# #N/A
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# #N/A
# #N/A
# #N/A
# #N/A
# #N/A
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# #N/A
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# Employer Provided Salary:₹3L
# Employer Provided Salary:
# ₹3L
# 10 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# #N/A
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# #N/A
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# #N/A
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# #N/A
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# 11 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# #N/A
# ₹4L - ₹7L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹7L
# 12 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# #N/A
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹15L - ₹20L
# Employer Provided Salary:
# ₹15L - ₹20L
# 13 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# #N/A
# #N/A
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹10T
# Employer Provided Salary:
# ₹10T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# 14 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# #N/A
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# #N/A
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# Employer Provided Salary:₹10T
# Employer Provided Salary:
# ₹10T
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# #N/A
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# 15 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# #N/A
# #N/A
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# #N/A
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹10T
# Employer Provided Salary:
# ₹10T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# 16 out of 30 pages done
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# #N/A
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# 17 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# #N/A
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹10T
# Employer Provided Salary:
# ₹10T
# 18 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# #N/A
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# 19 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# #N/A
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# 20 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# #N/A
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# #N/A
# 21 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹10T
# Employer Provided Salary:
# ₹10T
# 22 out of 30 pages done
# #N/A
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# #N/A
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# Employer Provided Salary:₹2L - ₹3L
# Employer Provided Salary:
# ₹2L - ₹3L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# #N/A
# #N/A
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# 23 out of 30 pages done
# #N/A
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# #N/A
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# #N/A
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# #N/A
# 24 out of 30 pages done
# #N/A
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# #N/A
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹11L
# Employer Provided Salary:
# ₹11L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# #N/A
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# #N/A
# 25 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# #N/A
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# ₹5L - ₹8L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹8L
# #N/A
# 26 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# #N/A
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# #N/A
# Employer Provided Salary:₹10T - ₹15T
# Employer Provided Salary:
# ₹10T - ₹15T
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# 27 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# #N/A
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# #N/A
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# #N/A
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# #N/A
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# #N/A
# Employer Provided Salary:₹2L - ₹3L
# Employer Provided Salary:
# ₹2L - ₹3L
# #N/A
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# 28 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# #N/A
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# #N/A
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# #N/A
# Employer Provided Salary:₹30T - ₹40T
# Employer Provided Salary:
# ₹30T - ₹40T
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# #N/A
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# #N/A
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# #N/A
# Employer Provided Salary:₹2L - ₹3L
# Employer Provided Salary:
# ₹2L - ₹3L
# 29 out of 30 pages done
# Employer Provided Salary:₹8L - ₹12L
# Employer Provided Salary:
# ₹8L - ₹12L
# #N/A
# Employer Provided Salary:₹8L - ₹11L
# Employer Provided Salary:
# ₹8L - ₹11L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹45L - ₹75L
# Employer Provided Salary:
# ₹45L - ₹75L
# Employer Provided Salary:₹7T - ₹8T
# Employer Provided Salary:
# ₹7T - ₹8T
# Employer Provided Salary:₹2L - ₹5L
# Employer Provided Salary:
# ₹2L - ₹5L
# Employer Provided Salary:₹1L
# Employer Provided Salary:
# ₹1L
# #N/A
# Employer Provided Salary:₹80T - ₹1L
# Employer Provided Salary:
# ₹80T - ₹1L
# Employer Provided Salary:₹5L - ₹16L
# Employer Provided Salary:
# ₹5L - ₹16L
# Employer Provided Salary:₹30T - ₹50T
# Employer Provided Salary:
# ₹30T - ₹50T
# Employer Provided Salary:₹40T - ₹50T
# Employer Provided Salary:
# ₹40T - ₹50T
# Employer Provided Salary:₹5L - ₹8L
# Employer Provided Salary:
# ₹5L - ₹8L
# #N/A
# #N/A
# ₹5L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹5L - ₹9L
# #N/A
# #N/A
# Employer Provided Salary:₹5T
# Employer Provided Salary:
# ₹5T
# Employer Provided Salary:₹50T
# Employer Provided Salary:
# ₹50T
# Employer Provided Salary:₹2L
# Employer Provided Salary:
# ₹2L
# Employer Provided Salary:₹4L - ₹6L
# Employer Provided Salary:
# ₹4L - ₹6L
# Employer Provided Salary:₹5L - ₹15L
# Employer Provided Salary:
# ₹5L - ₹15L
# Employer Provided Salary:₹12L
# Employer Provided Salary:
# ₹12L
# Employer Provided Salary:₹5L - ₹7L
# Employer Provided Salary:
# ₹5L - ₹7L
# Employer Provided Salary:₹40T - ₹80T
# Employer Provided Salary:
# ₹40T - ₹80T
# Employer Provided Salary:₹14L
# Employer Provided Salary:
# ₹14L
# ₹4L - ₹9L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹4L - ₹9L
# ₹3L - ₹5L (Glassdoor Est.)
# (Glassdoor Est.)
# ₹3L - ₹5L
# 30 out of 30 pages done
